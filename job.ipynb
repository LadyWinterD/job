# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv


with open('business_analyst.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)   


    def get_onepage(j):
        
        url="https://www.seek.co.nz/data-analyst-jobs/full-time?page="+str(j)+""
        r=requests.get(url)
        soup=BeautifulSoup(r.text,'html.parser')
        #print(str(soup))

        comment_list=soup.find_all('article')
        #print(comment_list)
        for item in comment_list:
            name=item.find('a').text.strip()
            company=item.find('a',class_="_2iNL7wI").text
            location=item.find('strong',class_="lwHBT6d").text

            print(name)
            print('--------------------------------------------   ')
            print(company)
            print('--------------------------------------------   ')
            print(location)
            print('--------------------------------------------   ')
            url2=re.findall('<a class="_2iNL7wI" data-automation="jobTitle" href="(.*?)" target="_self"',str(item))
            #print('https://www.seek.co.nz'+url2[0])
            url3='https://www.seek.co.nz'+url2[0]
            r1=requests.get(url3)
            soup=BeautifulSoup(r1.text,'html.parser')

            jobdes=soup.find_all('div',class_='templatetext')
            #print(jobdes) 
            employee_writer.writerow([name,company,location,url3])
            

    for k in range(80):
        get_onepage(k)
        print('Print page()'.format(k+1))
        time.sleep(3)
# Out:
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Research Analyst
# --------------------------------------------
# Senior Research Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Engineer.
# --------------------------------------------
# Data Engineer.
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Business Intelligence Specialist
# --------------------------------------------
# Business Intelligence Specialist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# TRADE MARKETING ANALYST
# --------------------------------------------
# TRADE MARKETING ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Process Analyst
# --------------------------------------------
# Data Process Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analytics Lead
# --------------------------------------------
# Data Analytics Lead
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Management Analyst
# --------------------------------------------
# Data Management Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Service Reporting Analyst
# --------------------------------------------
# Service Reporting Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Quality Analyst
# --------------------------------------------
# Data Quality Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Campaign Data Analyst and Planner
# --------------------------------------------
# Campaign Data Analyst and Planner
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Intermediate Data Scientist
# --------------------------------------------
# Intermediate Data Scientist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Research Analyst
# --------------------------------------------
# Senior Research Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Engineer.
# --------------------------------------------
# Data Engineer.
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# BUSINESS INFORMATION ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Business Intelligence Specialist
# --------------------------------------------
# Business Intelligence Specialist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# TRADE MARKETING ANALYST
# --------------------------------------------
# TRADE MARKETING ANALYST
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# Data Scientist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Process Analyst
# --------------------------------------------
# Data Process Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analytics Lead
# --------------------------------------------
# Data Analytics Lead
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Management Analyst
# --------------------------------------------
# Data Management Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Service Reporting Analyst
# --------------------------------------------
# Service Reporting Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Quality Analyst
# --------------------------------------------
# Data Quality Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# Senior Analyst - Data and Invest
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Campaign Data Analyst and Planner
# --------------------------------------------
# Campaign Data Analyst and Planner
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Intermediate Data Scientist
# --------------------------------------------
# Intermediate Data Scientist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Commercial Analyst
# --------------------------------------------
# Commercial Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Power Platform/Dynamics 365 CRM Business Analyst / Functional Consultant
# --------------------------------------------
# Power Platform/Dynamics 365 CRM Business Analyst / Functional Consultant
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Product Insights Analyst
# --------------------------------------------
# Product Insights Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Transport Analyst
# --------------------------------------------
# Transport Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Reporting Analyst
# --------------------------------------------
# Reporting Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Business Analyst (BI)
# --------------------------------------------
# Business Analyst (BI)
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Intelligence Analyst
# --------------------------------------------
# Business Intelligence Analyst
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# Senior Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Customer Insights Analyst with a twist
# --------------------------------------------
# Customer Insights Analyst with a twist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# Data Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Solution Analyst - Junior Functional Consultant (Auckland or Wellington based)
# --------------------------------------------
# Solution Analyst - Junior Functional Consultant (Auckland or Wellington based)
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Solution Analyst - Junior Functional Consultant (Auckland or Wellington based)
# --------------------------------------------
# Solution Analyst - Junior Functional Consultant (Auckland or Wellington based)
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Management Analyst (with a few other duties)
# --------------------------------------------
# Data Management Analyst (with a few other duties)
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Governance Specialist
# --------------------------------------------
# Data Governance Specialist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Intelligence Analyst - Financial Crime
# --------------------------------------------
# Intelligence Analyst - Financial Crime
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Customer Insights Analyst
# --------------------------------------------
# Customer Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Commercial Analyst
# --------------------------------------------
# Commercial Analyst
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Solution Analyst - Applications
# --------------------------------------------
# Solution Analyst - Applications
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Lead Data Analyst
# --------------------------------------------
# Lead Data Analyst
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Forensics Analyst / Senior Analyst
# --------------------------------------------
# Forensics Analyst / Senior Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Asset Analyst
# --------------------------------------------
# Asset Analyst
# --------------------------------------------
# location: TasmanTasman
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Business Analyst - BI/Data
# --------------------------------------------
# Senior Business Analyst - BI/Data
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Support Analyst
# --------------------------------------------
# Support Analyst
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Specialist
# --------------------------------------------
# Data Specialist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Analyst - Forecasting
# --------------------------------------------
# Senior Analyst - Forecasting
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Solution Analyst - Applications
# --------------------------------------------
# Solution Analyst - Applications
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Actuarial Analyst
# --------------------------------------------
# Actuarial Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# BI Analyst
# --------------------------------------------
# BI Analyst
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Business Insights Analyst
# --------------------------------------------
# Business Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Test Analyst - Data management
# --------------------------------------------
# Test Analyst - Data management
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data & Systems Operations Lead
# --------------------------------------------
# Data & Systems Operations Lead
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# CDO Reporting Analyst
# --------------------------------------------
# CDO Reporting Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Leader Pricing Analytics
# --------------------------------------------
# Leader Pricing Analytics
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# eCommerce Financial Data Analyst - 6 month Contract
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Analyst - Digital
# --------------------------------------------
# Data Analyst - Digital
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Asset Systems Analyst
# --------------------------------------------
# Asset Systems Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Intelligence Analyst
# --------------------------------------------
# Business Intelligence Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Analyst
# --------------------------------------------
# Financial Analyst
# --------------------------------------------
# location: OtagoOtago
# --------------------------------------------
# Analyst
# --------------------------------------------
# Analyst
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst - Business Intelligence
# --------------------------------------------
# Business Analyst - Business Intelligence
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Leader Pricing Analytics
# --------------------------------------------
# Leader Pricing Analytics
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Commercial Analyst
# --------------------------------------------
# Commercial Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# SACM Analyst
# --------------------------------------------
# SACM Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Supply Analyst Business Services
# --------------------------------------------
# Supply Analyst Business Services
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Hydrology / Water Data Scientist
# --------------------------------------------
# Hydrology / Water Data Scientist
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Application Support Analyst
# --------------------------------------------
# Application Support Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# Data Engineer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BI Developer
# --------------------------------------------
# BI Developer
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Technical Lead - Data
# --------------------------------------------
# Technical Lead - Data
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Applications Analyst
# --------------------------------------------
# Applications Analyst
# --------------------------------------------
# location: OtagoOtago
# --------------------------------------------
# Collections Analyst
# --------------------------------------------
# Collections Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Reporting Analyst
# --------------------------------------------
# Reporting Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analytics Systems Developer
# --------------------------------------------
# Business Analytics Systems Developer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# Product Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Data Modeller
# --------------------------------------------
# Senior Data Modeller
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Promotion/Rebates Analyst
# --------------------------------------------
# Promotion/Rebates Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Performance Analyst Programmer
# --------------------------------------------
# Performance Analyst Programmer
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Leader Pricing Analytics
# --------------------------------------------
# Leader Pricing Analytics
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst - 100-120K neg
# --------------------------------------------
# Business Analyst - 100-120K neg
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BI Specialist
# --------------------------------------------
# BI Specialist
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Intelligence Analyst/Developer
# --------------------------------------------
# Business Intelligence Analyst/Developer
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Intermediate Insights Analyst
# --------------------------------------------
# Intermediate Insights Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Analyst Junior
# --------------------------------------------
# Financial Analyst Junior
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# Analyst - Consumer Pricing and Portfolio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Database Developer
# --------------------------------------------
# Database Developer
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Insight Analyst
# --------------------------------------------
# Financial Insight Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Market Analyst - Infrastructure Projects North (Auckland)
# --------------------------------------------
# Market Analyst - Infrastructure Projects North (Auckland)
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Risk Analyst - SAS
# --------------------------------------------
# Risk Analyst - SAS
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Collections Analyst
# --------------------------------------------
# Collections Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Billing and Operations Analyst
# --------------------------------------------
# Billing and Operations Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Data Analyst / Data Analyst
# --------------------------------------------
# Senior Data Analyst / Data Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Analyst - People and Capability
# --------------------------------------------
# Analyst - People and Capability
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# Data Scientist x2
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Financial Planning Analyst
# --------------------------------------------
# Financial Planning Analyst
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Portfolio and Pricing Analyst - Ando
# --------------------------------------------
# Senior Portfolio and Pricing Analyst - Ando
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analytics and Insights Manager
# --------------------------------------------
# Analytics and Insights Manager
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
