# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv

import csv

with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)   


    def get_onepage(j):
        url="https://www.seek.co.nz/data-analyst-jobs/full-time?page="+str(j)+"&sortmode=ListedDate"
        r=requests.get(url)
        soup=BeautifulSoup(r.text,'html.parser')
        #print(str(soup))

        comment_list=soup.find_all('article')
        #print(comment_list)
        for item in comment_list:
            name=item.find('a').text.strip()
            company=item.find('a',class_="_3AMdmRg").text
            location=item.find('strong',class_="lwHBT6d").text

            print(name)
            print('--------------------------------------------   ')
            print(company)
            print('--------------------------------------------   ')
            print(location)
            print('--------------------------------------------   ')
            url2=re.findall('<a class="_2iNL7wI" data-automation="jobTitle" href="(.*?)" target="_self"',str(item))
            #print('https://www.seek.co.nz'+url2[0])
            url3='https://www.seek.co.nz'+url2[0]
            r1=requests.get(url3)
            soup=BeautifulSoup(r1.text,'html.parser')

            jobdes=soup.find_all('div',class_='templatetext')
            #print(jobdes) 
            employee_writer.writerow([name,company,location,url3])
            

    for k in range(67):
        get_onepage(k)
        print('Print page()'.format(k+1))
        time.sleep(2)
# Out:
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Pricing Specialist
# --------------------------------------------
# Hewlett Packard Enterprise
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Database Developer
# --------------------------------------------
# Randstad Technologies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Account Executive- Foodstuffs
# --------------------------------------------
# Johnson & Johnson
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Software Developer
# --------------------------------------------
# Randstad Technologies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Service Desk Analyst
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Subject Librarian
# --------------------------------------------
# Massey University
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Finance Administrator
# --------------------------------------------
# Ballance Agri-Nutrients
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Digital Insights Analyst
# --------------------------------------------
# Robert Walters
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Membership Support Administrator
# --------------------------------------------
# Recruitment Studio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Architect
# --------------------------------------------
# Datapoints
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BI/DW Developer
# --------------------------------------------
# Coca-Cola Amatil NZ Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Property Data Analyst
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Property Data Analyst
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Supply Chain Administrator
# --------------------------------------------
# Miraka Limited
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Finance Business Partner - Sales and Marketing
# --------------------------------------------
# Convergence Partners Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Development Manager - HVAC
# --------------------------------------------
# Johnson Controls
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Hospital Specialist
# --------------------------------------------
# Medacs Healthcare New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Pricing Specialist
# --------------------------------------------
# Hewlett Packard Enterprise
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Database Developer
# --------------------------------------------
# Randstad Technologies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Account Executive- Foodstuffs
# --------------------------------------------
# Johnson & Johnson
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Software Developer
# --------------------------------------------
# Randstad Technologies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Service Desk Analyst
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Subject Librarian
# --------------------------------------------
# Massey University
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Finance Administrator
# --------------------------------------------
# Ballance Agri-Nutrients
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Digital Insights Analyst
# --------------------------------------------
# Robert Walters
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Membership Support Administrator
# --------------------------------------------
# Recruitment Studio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Architect
# --------------------------------------------
# Datapoints
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# BI/DW Developer
# --------------------------------------------
# Coca-Cola Amatil NZ Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Property Data Analyst
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Property Data Analyst
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Supply Chain Administrator
# --------------------------------------------
# Miraka Limited
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Finance Business Partner - Sales and Marketing
# --------------------------------------------
# Convergence Partners Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Development Manager - HVAC
# --------------------------------------------
# Johnson Controls
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Key Account Executive - Alternative Channels
# --------------------------------------------
# Tribe (New Zealand) Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Regulatory Pricing Manager
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: NorthlandNorthland
# --------------------------------------------
# Analytics Lead Consultant - Microsoft Business Intelligence
# --------------------------------------------
# Theta
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Policy Analyst
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Network Performance Technician
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Network Performance Technician
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analytics Lead Consultant - Microsoft Business Intelligence
# --------------------------------------------
# Theta
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Information & Data Architect
# --------------------------------------------
# Younity Limited
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Software Developer - NIWA
# --------------------------------------------
# NIWA
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Waimea Dam Survey Manager
# --------------------------------------------
# Fulton Hogan
# --------------------------------------------
# location: TasmanTasman
# --------------------------------------------
# Analytics Lead Consultant (Hamilton) - Microsoft Business Intelligence
# --------------------------------------------
# Theta
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Lead/Senior Consultant - SQL Server/Datawarehouse Developer
# --------------------------------------------
# Theta
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Nationwide Product Sales Development Manager
# --------------------------------------------
# Aotea Security (NZ) Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Head of Digital
# --------------------------------------------
# TSB
# --------------------------------------------
# location: TaranakiTaranaki
# --------------------------------------------
# Management Accountant
# --------------------------------------------
# Parker Bridge – Global Recruiter Winners 2018 – Best Marketing Campaign
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Manager Customer Service Park to Plane
# --------------------------------------------
# Christchurch International Airport
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Lead Business/Data Analyst
# --------------------------------------------
# Ministry of Education
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Lead Business/Data Analyst
# --------------------------------------------
# Ministry of Education
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Retail Account Manager - NZ and the Pacific Islands
# --------------------------------------------
# RWR Executive
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Principal Planner
# --------------------------------------------
# NZDF
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Senior Financial Accountant 12 to 18 Month Contract
# --------------------------------------------
# Echelon Group Limited
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Schedule Coordinator- Hawkes Bay
# --------------------------------------------
# IHC
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Business Analyst / HRIS Systems / North Shore
# --------------------------------------------
# Enterprise Technology Recruitment Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Product Marketing Advisor
# --------------------------------------------
# Wellington Zoo Trust
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Strategy& Senior Analyst / Manager
# --------------------------------------------
# PwC NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# National Training Coordinator
# --------------------------------------------
# Johnson Controls
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Finance Analyst - Global FP&A
# --------------------------------------------
# Icebreaker
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Procurement Analyst
# --------------------------------------------
# DOWNER NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst (FCG)
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior UX & Insights Analyst
# --------------------------------------------
# Flux Federation
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Integration Software Engineer
# --------------------------------------------
# Recruit IT – Your IT Career and Contract Specialists
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# HR Manager
# --------------------------------------------
# Gerard Roofs (RoofTG Pacific)
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# HR/Quality Assurance & Personal Assistant
# --------------------------------------------
# Kinetic Recruitment
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# HR/Quality Assurance & Personal Assistant
# --------------------------------------------
# Kinetic Recruitment
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Junior Data Analyst
# --------------------------------------------
# Cavanagh & Associates Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Lead Data & Analytics Consultant
# --------------------------------------------
# Absolute IT - 98.9%* of placed candidates will recommend us to others
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Intermediate Software Engineer
# --------------------------------------------
# Absolute IT - 98.9%* of placed candidates will recommend us to others
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Practice Director - Data & Analytics (Wellington)
# --------------------------------------------
# Absolute IT - 98.9%* of placed candidates will recommend us to others
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Geo-Spatial Lead
# --------------------------------------------
# Absolute IT - 98.9%* of placed candidates will recommend us to others
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Analytics Lead
# --------------------------------------------
# Kiwibank
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Risk Analyst
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Test Analyst
# --------------------------------------------
# Ministry of Social Development
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Lead Business Analyst
# --------------------------------------------
# Rush Digital
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Geotechnical Engineer
# --------------------------------------------
# Beca
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Finance Business Partner - Operations
# --------------------------------------------
# Convergence Partners Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Property Manager - Building Compliance Focus
# --------------------------------------------
# Catholic Diocese of Auckland
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Administrator
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# General Manager
# --------------------------------------------
# NZDF
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Policy / Senior Policy Analyst
# --------------------------------------------
# Hays Policy & Strategy
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Asset and Network Manager
# --------------------------------------------
# Hays Property
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Supplier Relationship Manager, OCC
# --------------------------------------------
# Westpac
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Brand Support Reporting Analyst
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Brand Support Reporting Analyst
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Brand Support Reporting Analyst
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data and Reporting Analyst
# --------------------------------------------
# New Zealand Trade & Enterprise
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Data and Reporting Analyst
# --------------------------------------------
# New Zealand Trade & Enterprise
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Sales Manager
# --------------------------------------------
# MEA Mobile
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Digital Designer
# --------------------------------------------
# Waikato
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Receptionist/Administrator
# --------------------------------------------
# Forté Recruitment Ltd
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Frontline Station Support Officer
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Customer Acquisition Specialist - B2B
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Medical Clinic Manager
# --------------------------------------------
# All Care Family Medical Centre
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Customer Acquisition Manager - B2B
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Development Consultant
# --------------------------------------------
# Gallup
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Key Account Manager
# --------------------------------------------
# Sanofi
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Planning & Performance Reporting Advisors (x2)
# --------------------------------------------
# Momentum Consulting Group
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Head of UX
# --------------------------------------------
# New Zealand Racing Board
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Seed Production Field Technician
# --------------------------------------------
# AgResearch
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Orchard/Vineyard Supervisor
# --------------------------------------------
# VK CONTRACTING LTD
# --------------------------------------------
# location: Hawkes BayHawkes Bay
# --------------------------------------------
# Junior Financial Analyst
# --------------------------------------------
# Kinetic Recruitment
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Transition Manager
# --------------------------------------------
# Socialite Recruitment Ltd.
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Business Analyst (GIS)
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Accountant / Senior Accountant
# --------------------------------------------
# TMF Corporate Services New Zealand Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Content Producer
# --------------------------------------------
# Tribe (New Zealand) Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Network Engineer, healthAlliance - based in Penrose
# --------------------------------------------
# healthAlliance
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Network Engineer, healthAlliance - based in Penrose
# --------------------------------------------
# healthAlliance
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Key Account Manager - Foodstuffs South Island
# --------------------------------------------
# Goodman Fielder New Zealand Limited
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Management Accountant
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Business Analyst
# --------------------------------------------
# Ministry of Education
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Business Analyst
# --------------------------------------------
# Ministry of Education
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Principal Statistician
# --------------------------------------------
# Stats NZ
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Principal Statistician
# --------------------------------------------
# Stats NZ
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Customer Care Coordinator
# --------------------------------------------
# Hays Contact Centres
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Account Manager - Top Global Digital/CRM Agency - calling digital media execs!
# --------------------------------------------
# Metro Recruitment Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Lead Copywriter
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Plant Accountant
# --------------------------------------------
# Crescent Consulting
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Marketing Automation Executive
# --------------------------------------------
# Auckland University Of Technology
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Economist
# --------------------------------------------
# Hunter Campbell Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Passive Fire and Compliance Manager - Auckland
# --------------------------------------------
# Rob Law maxrecruitment
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# People and Performance Consultant
# --------------------------------------------
# Coretex
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Civil Construction Support Officer
# --------------------------------------------
# Palmerston North City Council
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Civil Construction Support Officer
# --------------------------------------------
# Palmerston North City Council
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Social Media Specialist
# --------------------------------------------
# Fonterra Co-operative Group Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Account Director
# --------------------------------------------
# Kin
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Problem Manager - Wellington
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Pricing and Analysis Manager
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Intermediate Business Analyst
# --------------------------------------------
# Presto Resourcing
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Financial Analyst
# --------------------------------------------
# Hunter Campbell Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Director - Integrated Safety Response
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Digital Marketing Coordinator - Waikato Museum
# --------------------------------------------
# Hamilton City Council
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Print page()
# Digital Marketing Coordinator - Waikato Museum
# --------------------------------------------
# Hamilton City Council
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# BRAND MANAGER WITH MILES CONTINENTAL
# --------------------------------------------
# NetYourJob
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Graduate role - Technology Associate September 2019 in take - New Zealand
# --------------------------------------------
# Infosys limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Systems Engineer
# --------------------------------------------
# WEL Networks
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Senior Business Systems Analyst - Diagnostics
# --------------------------------------------
# Canterbury District Health Board
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Senior Business Systems Analyst - Diagnostics
# --------------------------------------------
# Canterbury District Health Board
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Land Information Analyst
# --------------------------------------------
# Timaru District Council
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Service Desk Analyst
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Account/Customer Manager
# --------------------------------------------
# Rush Digital
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Payroll Administrator
# --------------------------------------------
# Adecco Accounting & Finance
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Wrangler - Kaiwhakaneke Raraunga
# --------------------------------------------
# Wellington
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# ADMINISTRATION AGENT 6 MONTH ASSIGNMENT
# --------------------------------------------
# Impex Personnel (NZ) Pty Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Analyst / Analyst, Business Reporting
# --------------------------------------------
# Oranga Tamariki
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Financial Data Analyst
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Analyst -  Corporate Finance
# --------------------------------------------
# PwC NZ
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Team Leader
# --------------------------------------------
# Advanced Personnel Services Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Category Analyst
# --------------------------------------------
# Nestle NZ Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Data Engineer
# --------------------------------------------
# Randstad Technologies
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Analyst
# --------------------------------------------
# Hays Office Support
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Service Desk Analyst - Wellington
# --------------------------------------------
# Vodafone New Zealand
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Operations Performance Lead
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Operations Performance Lead
# --------------------------------------------
# Auckland Transport
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# eCommerce Account & Strategy Manager
# --------------------------------------------
# Overdose Digital
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Software Asset Manager
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Internal Communications Advisor
# --------------------------------------------
# Flick Electric Co.
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Reliability Engineer
# --------------------------------------------
# WEL Networks
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# BI Platform Engineer
# --------------------------------------------
# Fisher & Paykel Appliances
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Analyst (FP&A)
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Planning Analyst
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Financial Analyst
# --------------------------------------------
# Hays Office Support
# --------------------------------------------
# location: OtagoOtago
# --------------------------------------------
# Lead Automation Test Engineer - Permanent, Wellington
# --------------------------------------------
# ACC
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Lead Automation Test Engineer - Permanent, Wellington
# --------------------------------------------
# ACC
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Financial Analyst
# --------------------------------------------
# Hays Office Support
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Administrator
# --------------------------------------------
# Access Community Health
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Development Manager
# --------------------------------------------
# Lloyd Executive Ltd
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Advisor (Addictions) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Advisor (Addictions) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Administration Assistant / Receptionist
# --------------------------------------------
# Forté Recruitment Ltd
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Advisor (Drug Intelligence) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Advisor (Drug Intelligence) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Pricing Manager
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Advisor (Addictions) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Advisor (Addictions) - Mental Health and Addiction
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Administrator
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Procurement Buyer
# --------------------------------------------
# Oceania Dairy Ltd
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Digital Business Manager
# --------------------------------------------
# Dentsu Aegis Network
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Data Analyst
# --------------------------------------------
# Ministry of Business, Innovation and Employment
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Telephone Account Executive
# --------------------------------------------
# EROAD Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Advisor (Drug Intelligence)
# --------------------------------------------
# Ministry of Health
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Reliability Engineer
# --------------------------------------------
# Wel Networks
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Data Systems Engineer
# --------------------------------------------
# Wel Networks
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Experience Design (CX) Consultant
# --------------------------------------------
# Deloitte - NZ
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Experience Design (CX) Consultant
# --------------------------------------------
# Deloitte - NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Experience Design (CX) Manager
# --------------------------------------------
# Deloitte - NZ
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Head of Solution Architecture
# --------------------------------------------
# Potentia: New Zealand’s Most Awarded IT Recruitment Consultancy*
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# G&D Specialist
# --------------------------------------------
# easy payroll
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Corporate Accountant
# --------------------------------------------
# Archway Recruitment
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Administration / Office Manager
# --------------------------------------------
# OneStaff Auckland
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Data Architect
# --------------------------------------------
# Talent – Winner Seek Medium Recruitment Agency of the year 4 years running
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Marketing Coordinator : Iconic Global Brand
# --------------------------------------------
# Bright NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Manager Data Management
# --------------------------------------------
# Talent – Winner Seek Medium Recruitment Agency of the year 4 years running
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Concept Design Manager
# --------------------------------------------
# DB Breweries Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Office Administration Assistant
# --------------------------------------------
# Wells Hygiene
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Quality Assurance Engineer
# --------------------------------------------
# Accedo Broadband
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Solution Architect
# --------------------------------------------
# ROLE
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Marketing Specialist
# --------------------------------------------
# Cucumber Limited
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# GM - Property, Retail and Parking Services - Sunshine Coast, QLD Location
# --------------------------------------------
# TROOCOO
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Planning &Optimisation Analyst
# --------------------------------------------
# Hays Logistics
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Quarantine Officer - Auckland
# --------------------------------------------
# Ministry for Primary Industries
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Manager Data Management/BI - to $155K, neg
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: WellingtonWellington
# ...
# location: AucklandAuckland
# --------------------------------------------
# Infrastructure Architect
# --------------------------------------------
# Global Attract Experis
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# General Manager - Sales & Marketing
# --------------------------------------------
# HR Connect Ltd
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Digital Marketing (Junior SEM Specialist)
# --------------------------------------------
# Aura Consulting
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Account Executive - Marketing and Communications
# --------------------------------------------
# people&co.
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# IT Service Technician
# --------------------------------------------
# PCSC
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Commercial Analyst
# --------------------------------------------
# TalentID Recruitment Ltd
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Consultant Integration Developer
# --------------------------------------------
# Recruit IT – Your IT Career and Contract Specialists
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Payroll Officer
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Receptionist/Agency Front of House
# --------------------------------------------
# Auckland
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Sales & Operations Planning Manager
# --------------------------------------------
# Alexander James Limited
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Office Administrator
# --------------------------------------------
# Chatfield & Co. Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Marketing Automation Consultant
# --------------------------------------------
# krunch.co
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# SEM/PPC Specialist
# --------------------------------------------
# Media Co
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Product Marketing Manager
# --------------------------------------------
# Vend
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Accounts Receivables Team-Lead, Assistant Manager
# --------------------------------------------
# NZ Uniforms
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Accounts Payables Team Lead, Assistant Manager
# --------------------------------------------
# NZ Uniforms
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Print page()
# Sales Coordinator
# --------------------------------------------
# Madison Recruitment Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Research Operations Coordinator
# --------------------------------------------
# Volpara Health Technologies Limited
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Digital Marketing Manager
# --------------------------------------------
# people&co.
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Developer - Dynamics NAV / 365
# --------------------------------------------
# Fujitsu New Zealand
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Area Sales Manager
# --------------------------------------------
# Allflex Australia
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Science Support and Operations Coordinator
# --------------------------------------------
# Volpara Health Technologies Limited
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Software Engineer
# --------------------------------------------
# Aderant
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Outbound Telesales Representative
# --------------------------------------------
# Paymark
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Outage Planner and Scheduler
# --------------------------------------------
# Contact Energy
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Supply Chain / Procurement Administrator
# --------------------------------------------
# Metro Performance Glass
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Sales Manager
# --------------------------------------------
# Momentum Consulting Group
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Operations Development Consultant
# --------------------------------------------
# H2R Consulting
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Administration Assistant
# --------------------------------------------
# RPL Services Limited
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Operations Development Consultant
# --------------------------------------------
# H2R Consulting
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Demand Planner
# --------------------------------------------
# Manuka Health
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Support Specialist
# --------------------------------------------
# Auckland
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Developer - Dynamics NAV / 365
# --------------------------------------------
# Fujitsu New Zealand
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Manager
# --------------------------------------------
# MyAdvisor
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Inside Sales Support
# --------------------------------------------
# Westcon – Comstor
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Database Specialist - Supporter Services
# --------------------------------------------
# The Fred Hollows Foundation NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Print page()
# Senior Business Account Manager
# --------------------------------------------
# Spark New Zealand Trading Limited
# --------------------------------------------
# location: ManawatuManawatu
# --------------------------------------------
# Account Manager
# --------------------------------------------
# World Vision NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Business Analyst
# --------------------------------------------
# Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Geotechnical Engineer
# --------------------------------------------
# Hays Engineering
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Principal Adviser - Service Design Implementation
# --------------------------------------------
# Starfish Consulting
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Electrical Engineer
# --------------------------------------------
# Lawson Williams Specialist Recruitment
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Product Architect - FinWeb
# --------------------------------------------
# Xero
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Marketing Coordinator
# --------------------------------------------
# Teletrac Navman
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Digital Marketing Manager
# --------------------------------------------
# Movio
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Lecturer / Senior Lecturer - Investments and Financial Risk Management
# --------------------------------------------
# Lincoln University
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Management Accountant - Maternity Cover
# --------------------------------------------
# IT Job Search Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Team Lead and Business Analyst
# --------------------------------------------
# Victoria University of Wellington
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Research Analyst
# --------------------------------------------
# Colliers International NZ Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Quality Manager
# --------------------------------------------
# Future Skills
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Ad Ops Manager
# --------------------------------------------
# razzbri Recruitment Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Project Services Team Lead
# --------------------------------------------
# Datacom is one of Australasia’s largest professional IT services companies
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Business Analyst - Strategy
# --------------------------------------------
# Hynds
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Production Planner
# --------------------------------------------
# Graham Consulting
# --------------------------------------------
# location: CanterburyCanterbury
# --------------------------------------------
# Senior Business Analyst
# --------------------------------------------
# BP
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Asset Management Specialist - Rivers and Drainage
# --------------------------------------------
# Bay of Plenty Regional Council
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Print page()
# Project Support Office Advisor
# --------------------------------------------
# Infuse Recruitment
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Sales & Marketing Analyst
# --------------------------------------------
# Gunn Talent
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Prosecutions Support Officer
# --------------------------------------------
# New Zealand Police
# --------------------------------------------
# location: WaikatoWaikato
# --------------------------------------------
# Head of Network Services
# --------------------------------------------
# 920
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Shop Supervisor
# --------------------------------------------
# Scientific & Technical Recruitment Limited
# --------------------------------------------
# location: Bay of PlentyBay of Plenty
# --------------------------------------------
# Customer Success Manager (CSM) - Global leading SaaS provider
# --------------------------------------------
# Arlo Software Limited
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# Senior Manager Treasury Finance
# --------------------------------------------
# Find Recruitment Limited
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Customer Analytics Associate Director
# --------------------------------------------
# PwC NZ
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Senior Full Stack Engineer (Front-end focused)
# --------------------------------------------
# Parrot Analytics Ltd
# --------------------------------------------
# location: AucklandAuckland
# --------------------------------------------
# Management Accountant - Kaikaute Pūtea
# --------------------------------------------
# Te Runanga o Toa Rangatira Inc
# --------------------------------------------
# location: WellingtonWellington
# --------------------------------------------
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-59-60b3a48b5168> in <module>
#      42
#      43     for k in range(67):
# ---> 44         get_onepage(k)
#      45         print('Print page()'.format(k+1))
#      46         time.sleep(2)
#
# <ipython-input-59-60b3a48b5168> in get_onepage(j)
#      38             jobdes=soup.find_all('div',class_='templatetext')
#      39             #print(jobdes)
# ---> 40             employee_writer.writerow([name,company,location,url3])
#      41
#      42
#
# ~\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u016b' in position 34: character maps to <undefined>
